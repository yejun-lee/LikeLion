# %%
import pandas as pd

# %%
med = pd.read_csv('C:/Users/user/LikeLion_AI/data/CSV/Medical_Check_1_50000.csv')
med_100 = pd.read_csv('C:/Users/user/LikeLion_AI/data/CSV/Medical_Check_1_1000000.csv')
med_100
# Out:
#         기준년도  가입자 일련번호  시도코드  성별코드  연령대 코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 0       2019         1    11     1            13        165          65  90.0
# 1       2019         2    48     2             5        155          45  64.0
# 2       2019         3    41     1            13        160          70  87.0
# 3       2019         4    28     1            12        170          60  85.0
# 4       2019         5    41     1            10        170          70  81.2
# ...      ...       ...   ...   ...           ...        ...         ...   ...
# 999995  2019    999996    41     1            12        170          65  80.0
# 999996  2019    999997    11     1             9        170          55  75.0
# 999997  2019    999998    45     1            13        160          65  92.3
# 999998  2019    999999    30     1             8        170          75  85.0
# 999999  2019   1000000    11     2            10        155          65  86.0
#
# ...

# %% [markdown]
# 11 서울특별시 41 경기도 42 강원도
#
# 26 부산광역시 27 대구광역시 28 인천광역시 29 광주광역시 30 대전광역시 31 울산광역시 36 세종특별자치시
#
# 43 충청북도 44 충청남도 45 전라북도 46 전라남도 47 경상북도 48 경상남도 50 제주특별자치도

# %% [markdown]
# ```python
# med1['시도코드'] = med1['시도코드'].map({11: '서울특별시', 41: '경기도', 42: '강원도', 26: '부산광역시', 27: '대구광역시', 28: '인천광역시',
#                                  29: '광주광역시', 30: '대전광역시', 31: '울산광역시', 36: '세종특별자치시',
#                                  43: '충청북도', 44: '충청남도', 45: '전라북도', 46: '전라남도', 47: '경상북도', 48: '경상남도', 49: '제주특별자치도'})
#
# med1['시도코드']
# ```

# %%
med_101 = med_100.drop(['결손치 유무', '치아마모증유무', '제3대구치(사랑니) 이상'], axis=1)
print(med_101['시도코드'].value_counts().sort_index())   # 값을 세면서 오름차순 배열
# med_101.sort_values(by='시도코드')
# Out:
# 11    179491
# 26     66484
# 27     46409
# 28     58555
# 29     27327
# 30     29423
# 31     24162
# 36      5474
# 41    255131
# 42     29769
# 43     33588
# 44     43047
# 45     35218
# 46     36138
# 47     52472
# 48     66202
# 50     11110
# Name: 시도코드, dtype: int64

# %%
med_101.columns
# Out:
# Index(['기준년도', '가입자 일련번호', '시도코드', '성별코드', '연령대 코드(5세단위)', '신장(5Cm단위)',
#        '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기 혈압',
#        '이완기 혈압', '식전혈당(공복혈당)', '총 콜레스테롤', '트리글리세라이드', 'HDL 콜레스테롤', 'LDL 콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마 지티피', '흡연상태',
#        '음주여부', '구강검진 수검여부', '치아우식증유무', '치석', '데이터 공개일자'],
#       dtype='object')

# %%
sido_11 = med_101.loc[med_101['시도코드']==11, :].head(5000)
sido_26 = med_101.loc[med_101['시도코드']==26, :].head(5000)
sido_27 = med_101.loc[med_101['시도코드']==27, :].head(5000)
sido_28 = med_101.loc[med_101['시도코드']==28, :].head(5000)

sido_29 = med_101.loc[med_101['시도코드']==29, :].head(5000)
sido_30 = med_101.loc[med_101['시도코드']==30, :].head(5000)
sido_31 = med_101.loc[med_101['시도코드']==31, :].head(5000)
sido_36 = med_101.loc[med_101['시도코드']==36, :].head(5000)

sido_41 = med_101.loc[med_101['시도코드']==41, :].head(5000)
sido_42 = med_101.loc[med_101['시도코드']==42, :].head(5000)
sido_43 = med_101.loc[med_101['시도코드']==43, :].head(5000)
sido_44 = med_101.loc[med_101['시도코드']==44, :].head(5000)

sido_45 = med_101.loc[med_101['시도코드']==45, :].head(5000)
sido_46 = med_101.loc[med_101['시도코드']==46, :].head(5000)
sido_47 = med_101.loc[med_101['시도코드']==47, :].head(5000)
sido_48 = med_101.loc[med_101['시도코드']==48, :].head(5000)
sido_50 = med_101.loc[med_101['시도코드']==50, :].head(5000)

# %%
med_102 = pd.concat([sido_11, sido_26, sido_27, sido_28, 
                    sido_29, sido_30, sido_31, sido_36, 
                    sido_41, sido_42, sido_43, sido_44, 
                    sido_45, sido_46, sido_47, sido_48, 
                    sido_50], ignore_index=True)

med_102  # 시도 별로 5000명씩 추출한 데이터 프레임
# Out:
#        기준년도  가입자 일련번호  시도코드  성별코드  연령대 코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)   허리둘레  \
# 0      2019         1    11     1            13        165          65   90.0
# 1      2019         6    11     1             8        170         110  107.8
# 2      2019         8    11     1            12        165          65   85.0
# 3      2019        10    11     2            13        145          50   78.0
# 4      2019        12    11     1             6        170          80   92.0
# ...     ...       ...   ...   ...           ...        ...         ...    ...
# 84995  2019    440133    50     1            13        165          80   95.0
# 84996  2019    440355    50     1            12        160          70   95.0
# 84997  2019    440356    50     1             6        170          60   71.0
# 84998  2019    440434    50     2            11        155          80  110.0
# 84999  2019    440676    50     2            13        155          65   98.0
#
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

med_101.groupby(['시도코드', '연령대 코드(5세단위)', '성별코드'])['신장(5Cm단위)'].mean()
# Out:
# 시도코드  연령대 코드(5세단위)  성별코드
# 11    5             1       172.145170
#                     2       159.407666
#       6             1       172.802668
#                     2       159.823808
#       7             1       172.902224
#                     2       159.846743
#       8             1       172.713330
#                     2       159.537718
#       9             1       171.448108
#                     2       158.600373
#       10            1       170.200687
#                     2       157.270529
#       11            1       168.593319
#                     2       155.633589
#       12            1       166.931344
#                     2       154.360081
#       13            1       165.687206
#                     2       153.073448
#       14            1       164.111868
#                     2       151.651575
#       15            1       163.514056
#                     2       150.651434
#       16            1       162.238969
# ...

# %% [markdown]
# ```
# 1 0~4세    10 45~49세
# 2 5~9세    11 50~54세
# 3 10~14세  12 55~59세
# 4 15~19세  13 60~64세
# 5 20~24세  14 65~69세
# 6 25~29세  15 70~74세
# 7 30~34세  16 75~79세
# 8 35~39세  17 80~84세
# 9 40~44세  18 85세+
# ```

# %%
med_100.value_counts('연령대 코드(5세단위)').sort_index()
# Out:
# 연령대 코드(5세단위)
# 5      32953
# 6      70314
# 7      82067
# 8      85019
# 9     119107
# 10    109661
# 11    128758
# 12    102992
# 13    112532
# 14     53733
# 15     53789
# 16     26337
# 17     18387
# 18      4351
# dtype: int64

# %%
age_5 = med_100.loc[med_100['연령대 코드(5세단위)']==5, :].head(15000)
age_6 = med_100.loc[med_100['연령대 코드(5세단위)']==6, :].head(15000)
age_7 = med_100.loc[med_100['연령대 코드(5세단위)']==7, :].head(15000)
age_8 = med_100.loc[med_100['연령대 코드(5세단위)']==8, :].head(15000)

age_9 = med_100.loc[med_100['연령대 코드(5세단위)']==9, :].head(15000)
age_10 = med_100.loc[med_100['연령대 코드(5세단위)']==10, :].head(15000)
age_11 = med_100.loc[med_100['연령대 코드(5세단위)']==11, :].head(15000)
age_12 = med_100.loc[med_100['연령대 코드(5세단위)']==12, :].head(15000)

age_13 = med_100.loc[med_100['연령대 코드(5세단위)']==13, :].head(15000)
age_14 = med_100.loc[med_100['연령대 코드(5세단위)']==14, :].head(15000)
age_15 = med_100.loc[med_100['연령대 코드(5세단위)']==15, :].head(15000)
age_16 = med_100.loc[med_100['연령대 코드(5세단위)']==16, :].head(15000)

age_17 = med_100.loc[med_100['연령대 코드(5세단위)']==17, :].head(15000)
age_18 = med_100.loc[med_100['연령대 코드(5세단위)']==18, :].head(4351)

# %%
med_103 = pd.concat([age_5, age_6, age_7, age_8, 
                    age_9, age_10, age_11, age_12,
                    age_13, age_14, age_15, age_16,
                    age_17, age_18], ignore_index=True)

med_103.shape   # 연령대별 15000명(85세 이상=4351명) 데이터 프레임
# Out:
# (199351, 34)

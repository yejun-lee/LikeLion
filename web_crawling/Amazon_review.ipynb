# %% [markdown]
# ### 아마존 리뷰 정보 가져오기
# 1. 사용자 정보
# 2. 평점
# 3. 날짜
# 4. 지역 정보, 몇 명에게 도움이 되었다.

# %%
import os, warnings
import re
import time
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup

### 물품 검색
warnings.filterwarnings(action='ignore')

driver = webdriver.Chrome('./chromedriver_90')
url = 'https://www.amazon.com/'
driver.get(url)

sel_search = driver.find_element_by_xpath('//*[@id="twotabsearchtextbox"]')
sel_button = driver.find_element_by_xpath('//*[@id="nav-search-submit-button"]')

time.sleep(1)
sel_search.clear()   # 검색창 clear
time.sleep(1)
sel_search.send_keys('earphone')   # 이어폰 검색
time.sleep(1)
sel_button.click()   # 검색버튼 클릭
time.sleep(1)

# %%
### 상품 목록 중 첫 번째 상품 선택
sel_a = driver.find_elements_by_xpath('//*[@id="search"]/div[1]/div/div[1]/div/span[3]/div[2]')

for i in sel_a:
    sel_b = i.find_elements_by_tag_name('h2')
    for j in sel_b:
        if j.text:
            try:
                print('제품명 : ', j.text)
                print('url : ', j.find_element_by_tag_name('a').get_attribute('href'))
                print()
                one_url = j.find_element_by_tag_name('a').get_attribute('href')
                break
            except:
                print('url : Fail')
                print()
                continue
    break
    
time.sleep(1)
driver.get(one_url)
time.sleep(1)

## 리뷰 창 띄우기
rating = driver.find_element_by_xpath('//*[@id="acrCustomerReviewText"]')
print(rating.text)
rating.click()
time.sleep(2)

## 모든 리뷰 보기 창
all_review = driver.find_element_by_xpath('//*[@id="reviews-medley-footer"]/div[2]/a')
all_review.click()
time.sleep(1)
# Out:
# 제품명 :  Amazon Basics In-Ear Wired Headphones Earbuds with Microphone, Red
# url :  https://www.amazon.com/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A049053719V83R4ZNWDQA&url=%2FAmazonBasics-17E13RD-Ear-Headphones-Mic%2Fdp%2FB07HH223KV%2Fref%3Dsr_1_1_sspa%3Fdchild%3D1%26keywords%3Dearphones%26qid%3D1624258995%26sr%3D8-1-spons%26psc%3D1&qualifier=1624258995&id=7076510246670124&widgetName=sp_atf
#
# 6,541 ratings

# %%
reviews = []
names = []
stars = []
dates = []
countrys = []
helpfuls = []
            
### 정보 긁어오기
for pg in range(5):    # 페이지 수
    page = driver.page_source
    soup = BeautifulSoup(page, 'lxml')
    
    next_button = driver.find_element_by_xpath('//*[@id="cm_cr-pagination_bar"]/ul/li[2]/a')
    print('==================')
    print('page', pg+1, 'Crawling...')
    print('==================')
    
    review_list = soup.findAll('span', class_='a-size-base review-text review-text-content')
    for review in review_list:
        reviews.append(review.text.strip())

    name_list = soup.findAll('span', class_='a-profile-name')
    for name in name_list[2:]:
        names.append(name.text)

    star_list = soup.findAll('a', class_='a-link-normal')
    for star in star_list:
        star_1 = star.findAll('span', class_='a-icon-alt')
        for st in star_1:
            stars.append(st.text)

    date_list = soup.findAll('span', class_="a-size-base a-color-secondary review-date")
    for date in date_list[2:]:
        countrys.append(date.text.split(' on ')[0])
        dates.append(date.text.split(' on ')[1])

    helpful_list = soup.findAll('span', class_="cr-vote")
    for helpful in helpful_list:
        help_1 = helpful.text.split('\n')
        for one in range(1, len(help_1), 6):
            if not help_1[one]:  
                helpfuls.append('0 people found this helpful')
            else:
                helpfuls.append(help_1[one])
    
    time.sleep(3)
    next_button.click()
    time.sleep(3)  
#     driver.execute_script('window.scrollTo(0, 3500);')

print('======================')
print('Done')
print('======================')
# Out:
# ==================
# page 1 Crawling...
# ==================
# ==================
# page 2 Crawling...
# ==================
# ==================
# page 3 Crawling...
# ==================
# ==================
# page 4 Crawling...
# ==================
# ==================
# page 5 Crawling...
# ==================
# ======================
# Done
# ======================

# %%
## 파일로 변환
total_review = {'날짜':dates , '국가':countrys , '이름':names , '평점':stars ,
                '리뷰':reviews , '도움':helpfuls}

total_review = pd.DataFrame(total_review)
total_review
# Out:
#                     날짜                             국가                    이름  \
# 0       March 22, 2019  Reviewed in the United States           Rick Layton
# 1        April 3, 2019  Reviewed in the United States                 Emily
# 2        April 2, 2019  Reviewed in the United States                 romeo
# 3    February 11, 2019  Reviewed in the United States                 Ed W.
# 4    February 28, 2019  Reviewed in the United States           Sunderrajan
# 5       March 22, 2019  Reviewed in the United States              Brandy C
# 6    February 11, 2019  Reviewed in the United States               Daniel
# 7       March 26, 2019  Reviewed in the United States                   Vee
# 8        July 21, 2020  Reviewed in the United States                 Bob K
# 9       April 12, 2020  Reviewed in the United States     Robert Beauregard
# 10        June 4, 2019  Reviewed in the United States                 seiei
# 11      March 12, 2019  Reviewed in the United States                 Annie
# 12   September 2, 2019  Reviewed in the United States                kevinf
# 13     October 6, 2019  Reviewed in the United States            Greenbeans
# 14        May 27, 2021  Reviewed in the United States             CobaltLTH
# 15        May 27, 2019  Reviewed in the United States                Sean B
# 16   February 14, 2020  Reviewed in the United States                  Char
# 17       July 16, 2019  Reviewed in the United States                  Jami
# 18      March 31, 2020  Reviewed in the United States          A Reader NYC
# 19       June 19, 2019  Reviewed in the United States            Heather W.
# 20      March 18, 2019  Reviewed in the United States      Rose in Portland
# 21       March 6, 2021  Reviewed in the United States       Kindle Customer
# 22       April 6, 2019  Reviewed in the United States          Rainbow Eyes
# 23      March 14, 2019  Reviewed in the United States            Jon Janaka
# 24     August 26, 2020  Reviewed in the United States        Giselle Garcia
# 25       June 18, 2019  Reviewed in the United States                Tamara
# 26    October 20, 2020  Reviewed in the United States                 Julia
# 27   December 31, 2019  Reviewed in the United States                    PC
# 28  September 15, 2020  Reviewed in the United States        Ultimate Mommy
# 29    October 12, 2019  Reviewed in the United States                pbpvol
# 30       July 28, 2020  Reviewed in the United States            J. La Tour
# 31      March 30, 2020  Reviewed in the United States            W. Dempsey
# 32   February 12, 2019  Reviewed in the United States                 Becca
# 33    October 27, 2020  Reviewed in the United States                    RJ
# 34        June 7, 2021  Reviewed in the United States                   KLC
# 35       July 26, 2019  Reviewed in the United States           Teresa Clow
# 36   February 10, 2020  Reviewed in the United States           dostatochno
# 37      April 13, 2020  Reviewed in the United States            Christy W.
# 38         May 4, 2019  Reviewed in the United States       Nicholas Zulick
# 39  September 17, 2020  Reviewed in the United States      Benjamin Perkins
# 40        July 6, 2019  Reviewed in the United States              Rachel K
# 41  September 15, 2019  Reviewed in the United States                 Drewk
# 42      March 16, 2019  Reviewed in the United States            Green Tree
# 43    November 4, 2020  Reviewed in the United States            AutumnSkye
# 44   September 9, 2020  Reviewed in the United States            VAsunshine
# 45      March 27, 2021  Reviewed in the United States          Lainey Marie
# 46  September 20, 2019  Reviewed in the United States                 Debra
# 47       June 26, 2020  Reviewed in the United States  GioVanni Spallanzani
# 48       June 18, 2021  Reviewed in the United States                 JWL54
# 49      March 24, 2019  Reviewed in the United States            Nerdlinger
#
#                     평점                                                 리뷰  \
# 0   2.0 out of 5 stars  I made a mistake. The original Earpods that ca...
# 1   5.0 out of 5 stars  These are very inexpensive headphones but they...
# 2   1.0 out of 5 stars  The cables are very flimsy and thin, similar t...
# 3   5.0 out of 5 stars  The Amazon basic ear headphones works in the i...
# 4   4.0 out of 5 stars  I liked the color - my sons can't tell me that...
# 5   5.0 out of 5 stars  My 13 year old uses these on a daily basis. Sh...
# 6   2.0 out of 5 stars  They produce sound but it comes with a lot of ...
# 7   4.0 out of 5 stars  These headphones are surprisingly nice for the...
# 8   2.0 out of 5 stars  I usually buy Skullcandy Ink'd, but bought the...
# 9   5.0 out of 5 stars  Who'd have thunk it? Noise-canceling earbuds f...
# 10  1.0 out of 5 stars  The cable literately broke with no force, befo...
# 11  5.0 out of 5 stars  After 2.5 years with my trusty earbuds that ca...
# 12  4.0 out of 5 stars  I purchased the a white pair of AmazonBasics I...
# 13  4.0 out of 5 stars  They sound great, noise cancel unless kids are...
# 14  5.0 out of 5 stars  So I typically purchase the Panasonic wired ea...
# 15  2.0 out of 5 stars  The product came wrapped in bubble wrap and ta...
# 16  5.0 out of 5 stars  These seem comparable to the Apple wired earbu...
# 17  1.0 out of 5 stars  They were physically fine, comfortable and I d...
# 18  5.0 out of 5 stars  I bought these in white for $7.87 and also a p...
# 19  1.0 out of 5 stars  Sound constantly breaks up, heavy static. It's...
# 20  1.0 out of 5 stars  Worked for 2 weeks. Barely any sounds came out...
# 21  1.0 out of 5 stars  It's been a real long time since I've bought h...
# 22  5.0 out of 5 stars  These work well for me. Much lower price than ...
# 23  5.0 out of 5 stars  This is my second pair of Amazon Basics ear bu...
# 24  1.0 out of 5 stars  I’m a teacher and bought this product since we...
# 25  5.0 out of 5 stars  I bought these when I needed a pair of earbuds...
# 26  5.0 out of 5 stars  I mean, they're not Bose or Beats or anything ...
# 27  5.0 out of 5 stars  I have 2 pairs of earphones - these and the re...
# 28  3.0 out of 5 stars  I love pink! I needed a pair that my husband a...
# 29  1.0 out of 5 stars  Left earbud did not work right out of the box....
# 30  5.0 out of 5 stars  The first time i used them for a phone call th...
# 31  4.0 out of 5 stars  These headphones are bare-bones, you can hear ...
# 32  2.0 out of 5 stars  I bought these b/c the Amazon Basics HEADPHONE...
# 33  1.0 out of 5 stars  It was worth a try to get something in a hurry...
# 34  1.0 out of 5 stars  Even the smallest extra plug cover that come w...
# 35  5.0 out of 5 stars  I have a hard time finding comfortable in ear ...
# 36  2.0 out of 5 stars  Edit:  There just isn't enough strain relief f...
# 37  5.0 out of 5 stars  I used them for listening to music and playing...
# 38  4.0 out of 5 stars  I use headphones to watch videos during my mor...
# 39  5.0 out of 5 stars  Comfortable, inexpensive, and easy to keep tra...
# 40  2.0 out of 5 stars  I buy cheap earbuds because I have a tendency ...
# 41  1.0 out of 5 stars  The only reason these get one star is because ...
# 42  5.0 out of 5 stars  These headphones are very good for the price. ...
# 43  4.0 out of 5 stars  The sound isn’t as flat as I was expecting for...
# 44  4.0 out of 5 stars  With all the online meetings, these were neces...
# 45  1.0 out of 5 stars  Do not buy this product. I ordered these a few...
# 46  4.0 out of 5 stars  I left home without my earbuds and had to orde...
# 47  5.0 out of 5 stars  They're great, very inexpensive. I bought 3 to...
# 48  2.0 out of 5 stars  These disconnect on calls and continuously pau...
# 49  5.0 out of 5 stars  These have a solid bass, no tinny sound.  The ...
#
#                                도움
# 0    87 people found this helpful
# 1    63 people found this helpful
# 2    65 people found this helpful
# 3    40 people found this helpful
# 4    39 people found this helpful
# 5    30 people found this helpful
# 6    26 people found this helpful
# 7    21 people found this helpful
# 8     7 people found this helpful
# 9     4 people found this helpful
# 10    9 people found this helpful
# 11    3 people found this helpful
# 12    2 people found this helpful
# 13    4 people found this helpful
# 14    0 people found this helpful
# 15    4 people found this helpful
# 16  One person found this helpful
# 17    8 people found this helpful
# 18    0 people found this helpful
# 19    7 people found this helpful
# 20   12 people found this helpful
# 21    2 people found this helpful
# 22    7 people found this helpful
# 23  One person found this helpful
# 24    2 people found this helpful
# 25  One person found this helpful
# 26    0 people found this helpful
# 27  One person found this helpful
# 28    0 people found this helpful
# 29    3 people found this helpful
# 30  One person found this helpful
# 31    0 people found this helpful
# 32    3 people found this helpful
# 33    0 people found this helpful
# 34    0 people found this helpful
# 35  One person found this helpful
# 36    0 people found this helpful
# 37    0 people found this helpful
# 38    2 people found this helpful
# 39    0 people found this helpful
# 40  One person found this helpful
# 41    4 people found this helpful
# 42    4 people found this helpful
# 43    0 people found this helpful
# 44    0 people found this helpful
# 45  One person found this helpful
# 46    0 people found this helpful
# 47    0 people found this helpful
# 48    0 people found this helpful
# 49    5 people found this helpful

# %%
total_review.to_csv("Amazon_review.csv", index=False)

## 확인
print(os.getcwd())  # 현재 위치
print(os.listdir(os.getcwd()))
# Out:
# C:\Users\user\LikeLion_AI
# ['.ipynb_checkpoints', 'Amazon_review.csv', 'Amazon_review.ipynb', 'Amazon_selenium.ipynb', 'chromedriver_90.exe', 'data', 'dog_e.png', 'LLAI_06_09.ipynb', 'LLAI_06_14.ipynb', 'LLAI_06_16.ipynb', 'LLAI_06_17.ipynb', 'LLAI_06_18.ipynb', 'LLAI_06_21.ipynb', 'url.csv', 'Web_test.ipynb', '네이버 영화 정보.csv', '달라스바이어스클럽_리뷰_06_17.csv', '스파이더맨_리뷰_06_17.csv', '의료용어.csv', '인기종목 정보.csv', '회사명과 웹사이트.csv']

# %% [markdown]
# ### 길이를 확인해서 간결하게 확인해보기

# %%
print(len(dates))
print('--------')
print(len(countrys))
print('--------')
print(len(names))
print('--------')
print(len(stars))
print('--------')
print(len(reviews))
print('--------')
print(len(helpfuls))
print('--------')

# print(dates)
# print('--------')
# print(countrys)
# print('--------')
# print(names)
# print('--------')
# print(stars)
# print('--------')
# print(review_list)
# print('--------')
# print(helpfuls)
# print('--------')

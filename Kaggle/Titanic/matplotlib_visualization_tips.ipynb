# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# ## plt.subplot2grid()

# %%
fig = plt.figure(figsize=(8, 5), facecolor='white') # initialize figure

ax = [None for i in range(6)] # list to save many ax for setting parameter in each

ax[0] = plt.subplot2grid((3,4), (0,0), colspan=4)
ax[1] = plt.subplot2grid((3,4), (1,0), colspan=1)
ax[2] = plt.subplot2grid((3,4), (1,1), colspan=1)
ax[3] = plt.subplot2grid((3,4), (1,2), colspan=1)
ax[4] = plt.subplot2grid((3,4), (1,3), colspan=1,rowspan=2)
ax[5] = plt.subplot2grid((3,4), (2,0), colspan=3)


for ix in range(6): 
    ax[ix].set_title('ax[{}]'.format(ix)) # make ax title for distinguish:)
    ax[ix].set_xticks([]) # to remove x ticks
    ax[ix].set_yticks([]) # to remove y ticks
    
fig.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(8, 5), facecolor='white') # initialize figure

ax = [None for _ in range(6)] # list to save many ax for setting parameter in each

ax[0] = plt.subplot2grid((3,4), (0,0), colspan=4)
ax[1] = plt.subplot2grid((3,4), (1,0), colspan=1)
ax[2] = plt.subplot2grid((3,4), (1,1), colspan=1)
ax[3] = plt.subplot2grid((3,4), (1,2), colspan=1)
ax[4] = plt.subplot2grid((3,4), (1,3), colspan=1,rowspan=2)
ax[5] = plt.subplot2grid((3,4), (2,0), colspan=4)


for ix in range(6): 
    ax[ix].set_title('ax[{}]'.format(ix)) # make ax title for distinguish:)
    ax[ix].set_xticks([]) # to remove x ticks
    ax[ix].set_yticks([]) # to remove y ticks
    
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-dd938e7f90e9> in <module>
#      12
#      13 for ix in range(6):
# ---> 14     ax[ix].set_title('ax[{}]'.format(ix)) # make ax title for distinguish:)
#      15     ax[ix].set_xticks([]) # to remove x ticks
#      16     ax[ix].set_yticks([]) # to remove y ticks
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     186         if pad is None:
#     187             pad = rcParams['axes.titlepad']
# --> 188         self._set_title_offset_trans(float(pad))
#     189         title.set_text(label)
#     190         title.update(default)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _set_title_offset_trans(self, title_offset_points)
#    1200         self.titleOffsetTrans = mtransforms.ScaledTranslation(
#    1201                 0.0, title_offset_points / 72,
# -> 1202                 self.figure.dpi_scale_trans)
#    1203         for _title in (self.title, self._left_title, self._right_title):
#    1204             _title.set_transform(self.transAxes + self.titleOffsetTrans)
#
# AttributeError: 'NoneType' object has no attribute 'dpi_scale_trans'

# %% [markdown]
# ## .add_axes()

# %%
fig = plt.figure(figsize=(8, 5), facecolor='white')

ax = [None for _ in range(3)]


ax[0] = fig.add_axes([0.1, 0.5, 2, 0.4])    # x, y, dx, dy
ax[1] = fig.add_axes([0.15, 0.6, 0.25, 0.6])
ax[2] = fig.add_axes([0.5, 0.6, 0.4, 0.3])

for ix in range(3):
    ax[ix].set_title('ax[{}]'.format(ix))
    ax[ix].set_xticks([])
    ax[ix].set_yticks([])

plt.show()

# %% [markdown]
# ## .add_subplot()

# %%
fig = plt.figure(figsize=(8, 5), facecolor='white')

gs = fig.add_gridspec(3, 3) # make 3 by 3 grid (row, col)

ax = [None for _ in range(5)]

ax[0] = fig.add_subplot(gs[0, :]) 
ax[0].set_title('gs[0, :]')

ax[1] = fig.add_subplot(gs[1, :-1])
ax[1].set_title('gs[1, :-1]')

ax[2] = fig.add_subplot(gs[1:, -1])
ax[2].set_title('gs[1:, -1]')

ax[3] = fig.add_subplot(gs[-1, 0])
ax[3].set_title('gs[-1, 0]')

ax[4] = fig.add_subplot(gs[-1, -2])
ax[4].set_title('gs[-1, -2]')

for ix in range(5):
    ax[ix].set_xticks([])
    ax[ix].set_yticks([])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## .inset_axes()

# %%
import numpy as np

t = np.linspace(0, 2*np.pi, 100)
sine = np.sin(t)

fig, ax = plt.subplots(facecolor='white')
# fig = plt.plot(t, sine)

axin1 = ax.inset_axes([0.6, 0.5, 0.3, 0.3])
# axin1.plot(t, sine)

plt.show()

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

fig, ax = plt.subplots(1, 1, facecolor='white')
ax_divider = make_axes_locatable(ax)

ax = ax_divider.append_axes("right", size="7%", pad="2%")
ax.set_yticks([])
plt.tight_layout()
plt.show()

# %%
def cmap_plot(cmap_list, ctype):
    cmaps = cmap_list

    n = len(cmaps)

    fig = plt.figure(figsize=(8.25, n*.20), dpi=200, facecolor='white')
    ax = plt.subplot(1, 1, 1, frameon=False, xlim=[0,10], xticks=[], yticks=[])
    fig.subplots_adjust(top=0.99, bottom=0.01, left=0.18, right=0.99)

    y, dy, pad = 0, 0.3, 0.08

    ticks, labels = [], []

    for cmap in cmaps[::-1]:
        Z = np.linspace(0,1,512).reshape(1,512)
        plt.imshow(Z, extent=[0,10,y,y+dy], cmap=plt.get_cmap(cmap))
        ticks.append(y+dy/2)
        labels.append(cmap)
        y = y + dy + pad

    ax.set_ylim(-pad,y)
    ax.set_yticks(ticks)
    ax.set_yticklabels(labels)

    ax.tick_params(axis='y', which='both', length=0, labelsize=5)
    plt.title(f'{ctype} Colormap', fontweight='bold', fontsize=8)
    plt.show()

# %%
# _r mean reverse
diverge_cmap = ('PRGn', 'PiYG', 'RdYlGn', 'BrBG', 'RdGy', 'PuOr', 'RdBu', 'RdYlBu',  'Spectral', 'coolwarm_r', 'bwr_r', 'seismic_r')
cmap_plot(diverge_cmap, 'Diverging')

# %%
qualitative_cmap = ('tab10', 'tab20', 'tab20b', 'tab20c',
         'Pastel1', 'Pastel2', 'Paired',
         'Set1', 'Set2', 'Set3', 'Accent', 'Dark2' )

cmap_plot(qualitative_cmap, 'Qualitative')
